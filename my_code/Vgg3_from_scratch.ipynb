# %%
import numpy as np
#Set the `numpy` pseudo-random generator at a fixed value
#This helps with repeatable results everytime you run the code. 
np.random.seed(1000)

import matplotlib.pyplot as plt
import os
import cv2
from skimage.transform import resize  
from keras.utils import normalize
from sklearn.model_selection import train_test_split
from skimage import img_as_ubyte
from skimage.exposure import equalize_adapthist
import tensorflow as tf
import platform
import logging
logging.getLogger('tensorflow').disabled = True


#Iterate through all images in Parasitized folder, resize to 64 x 64
#Then save as numpy array with name 'dataset'
#Set the label to this as 0


def check_gpu():

    if 'linux' in platform.platform().lower():
        print("Check GPU...")
        if len(tf.config.list_physical_devices('GPU')) == 0:
            print("GPU is not available!")
            quit()

        print("GPU is available!")

check_gpu()

image_directory = "/home/abidhasan/Documents/Indicate_FH/data/"
figpath = '/home/abidhasan/Documents/Indicate_FH/performance_figures'
modelpath = '/home/abidhasan/Documents/Indicate_FH/saved_model'

epochs = 100
batch_size = 32
SIZE = 256
dataset = []  #Many ways to handle data, you can use pandas. Here, we are using a list format.  
label = []  #Place holders to define add labels. We will add 0 to all parasitized images and 1 to uninfected.


not_effected = os.listdir(image_directory + 'not_effected/')
for i, image_name in enumerate(not_effected):    #Remember enumerate method adds a counter and returns the enumerate object
    
    if (image_name.split('.')[1] == 'png'):
        image = cv2.imread(image_directory + 'not_effected/' + image_name) # Reading all the images using opencv as BGR format. 
        if (image is None):  # Checking is any image is an None type object or Not. If it is, then next imge is continued.
                continue
        # converting BGR to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #image = equalize_adapthist(image, kernel_size=None, clip_limit=0.1, nbins=256) # Applying the CLAHE to increase the contrast of the image
        image = img_as_ubyte(resize(image, (SIZE, SIZE), anti_aliasing=True)) 
        # Resizing the Image into size * size 
        # Converting an image to unsigned byte format, with values in [0, 255].
        dataset.append(np.array(image))
        label.append(0)

        
#Iterate through all images in Uninfected folder, resize to 64 x 64
#Then save into the same numpy array 'dataset' but with label 1

effected = os.listdir(image_directory + 'effected/')
for i, image_name in enumerate(effected):
    if (image_name.split('.')[1] == 'png'):
        image = cv2.imread(image_directory + 'effected/' + image_name)
        if (image is None):  # Checking is any image is an None type object or Not. If it is, then next imge is continued.
                continue
        # converting BGR to RGB
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        #image = equalize_adapthist(image, kernel_size=None, clip_limit=0.1, nbins=256) # Applying the CLAHE to increase the contrast of the image
        image = img_as_ubyte(resize(image, (SIZE, SIZE), anti_aliasing=True))
        # Resizing the Image into 256 * 256 
        # Converting an image to unsigned byte format, with values in [0, 255].
        dataset.append(np.array(image))
        label.append(1)


dataset = np.array(dataset)
print('Shape of dataset', dataset.shape)
label = np.array(label)

print('Shape of the labels', label.shape)

print('Count of the labels', np.unique(label, return_counts=True))

    
###############################################################    
    
 ### Split the dataset

# split the dataset into training and testing dataset.
# 1. Training data: 80%
# 2. Testing data: 20%

X_train, X_test, y_train, y_test = train_test_split(dataset, label, test_size = 0.20, random_state = 42)

#Without scaling (normalize) the training may not converge. 
#Normalization is a rescaling of the data from the original range 
#so that all values are within the range of 0 and 1.

X_train = normalize(X_train, axis=1)
X_test = normalize(X_test, axis=1)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# 2023-10-03 17:51:30.473780: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-10-03 17:51:30.495984: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-03 17:51:30.840121: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Check GPU...
# GPU is available!
# 2023-10-03 17:51:31.224248: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:51:31.238264: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:51:31.238391: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# Shape of dataset (8091, 256, 256, 3)
# Shape of the labels (8091,)
# Count of the labels (array([0, 1]), array([7203,  888]))
# (6472, 256, 256, 3)
# (1619, 256, 256, 3)
# (6472,)
# (1619,)

# %%
print('Count of the test labels', np.unique(y_test, return_counts=True))
# Out:
# Count of the test labels (array([0, 1]), array([1434,  185]))

# %%
#Apply CNN
# ### Build the model
from models import VGG3
#############################################################
###2 conv and pool layers. with some normalization and drops in between.
INPUT_SHAPE = (SIZE, SIZE, 3)   #change to (SIZE, SIZE, 3)
dropout_rt = 0.4
filter_size = 32
#model = my_model(filter_size, INPUT_SHAPE, dropout_rt)
model = VGG3(INPUT_SHAPE, dropout_rt)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 256, 256, 32)      896
#
#  conv2d_1 (Conv2D)           (None, 256, 256, 32)      9248
#
#  max_pooling2d (MaxPooling2D  (None, 128, 128, 32)     0
#  )
#
#  dropout (Dropout)           (None, 128, 128, 32)      0
#
#  conv2d_2 (Conv2D)           (None, 128, 128, 64)      18496
#
#  conv2d_3 (Conv2D)           (None, 128, 128, 64)      36928
#
#  max_pooling2d_1 (MaxPooling  (None, 64, 64, 64)       0
#  2D)
#
#  dropout_1 (Dropout)         (None, 64, 64, 64)        0
#
#  conv2d_4 (Conv2D)           (None, 64, 64, 128)       73856
#
#  conv2d_5 (Conv2D)           (None, 64, 64, 128)       147584
#
#  max_pooling2d_2 (MaxPooling  (None, 32, 32, 128)      0
#  2D)
#
#  dropout_2 (Dropout)         (None, 32, 32, 128)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dense (Dense)               (None, 128)               16777344
#
#  dropout_3 (Dropout)         (None, 128)               0
#
#  dense_1 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 17,064,481
# Trainable params: 17,064,481
# Non-trainable params: 0
# _________________________________________________________________
# 2023-10-03 17:54:55.397315: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.397499: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.397605: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.444750: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.444873: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.444939: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-10-03 17:54:55.444997: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22016 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9

# %%
history = model.fit(X_train, 
                         y_train, 
                         batch_size = batch_size, 
                         verbose = 1, 
                         epochs = epochs,      
                         validation_data=(X_test,y_test),
                         shuffle = False
                     )


#model.save(modelpath+'/VGG3_WITHOUT_AUG.h5')  



f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('CNN Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
max_epoch = len(history.history['accuracy'])+1
epoch_list = list(range(1, max_epoch))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")



ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
plt.show()

plt.savefig(figpath+'/VGG3_TRAIN_VS_VALIDATION_LOSS_WITHOUT_AUG.png', bbox_inches='tight')
# Out:
# Epoch 1/100
# 2023-10-03 17:55:07.684204: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:954] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape insequential/dropout/dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# 2023-10-03 17:55:07.785207: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-10-03 17:55:07.854883: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:231] Falling back to the CUDA driver for PTX compilation; ptxas does not support CC 8.9
# 2023-10-03 17:55:07.854901: W tensorflow/compiler/xla/stream_executor/gpu/asm_compiler.cc:234] Used ptxas at ptxas
# 2023-10-03 17:55:07.854960: W tensorflow/compiler/xla/stream_executor/gpu/redzone_allocator.cc:317] UNIMPLEMENTED: ptxas ptxas too old. Falling back to the driver to compile.
# Relying on driver to perform ptx compilation.
# Modify $PATH to customize ptxas location.
# This message will be only logged once.
# 2023-10-03 17:55:07.978575: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-10-03 17:55:07.992993: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x7f26e4e53bc0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-03 17:55:07.993014: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 4090, Compute Capability 8.9
# 2023-10-03 17:55:07.996520: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-03 17:55:08.048865: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 203/203 [==============================] - 11s 39ms/step - loss: 0.4050 - accuracy: 0.8908 - val_loss: 0.3664 - val_accuracy: 0.8857
# Epoch 2/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.3391 - accuracy: 0.8932 - val_loss: 0.3457 - val_accuracy: 0.8987
# Epoch 3/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.3225 - accuracy: 0.9047 - val_loss: 0.3254 - val_accuracy: 0.9036
# Epoch 4/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.3136 - accuracy: 0.9056 - val_loss: 0.3174 - val_accuracy: 0.9049
# Epoch 5/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2992 - accuracy: 0.9074 - val_loss: 0.2953 - val_accuracy: 0.9049
# Epoch 6/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2910 - accuracy: 0.9082 - val_loss: 0.2912 - val_accuracy: 0.9049
# Epoch 7/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2831 - accuracy: 0.9084 - val_loss: 0.2773 - val_accuracy: 0.9049
# Epoch 8/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2759 - accuracy: 0.9081 - val_loss: 0.2686 - val_accuracy: 0.9049
# Epoch 9/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2646 - accuracy: 0.9088 - val_loss: 0.2666 - val_accuracy: 0.9049
# Epoch 10/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2630 - accuracy: 0.9081 - val_loss: 0.2558 - val_accuracy: 0.9049
# Epoch 11/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2509 - accuracy: 0.9079 - val_loss: 0.2509 - val_accuracy: 0.9049
# Epoch 12/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2462 - accuracy: 0.9084 - val_loss: 0.2459 - val_accuracy: 0.9049
# Epoch 13/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2332 - accuracy: 0.9090 - val_loss: 0.2491 - val_accuracy: 0.9049
# Epoch 14/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2343 - accuracy: 0.9090 - val_loss: 0.2375 - val_accuracy: 0.9049
# Epoch 15/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2246 - accuracy: 0.9081 - val_loss: 0.2372 - val_accuracy: 0.9049
# Epoch 16/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2134 - accuracy: 0.9096 - val_loss: 0.2377 - val_accuracy: 0.9049
# Epoch 17/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2151 - accuracy: 0.9091 - val_loss: 0.2518 - val_accuracy: 0.9049
# Epoch 18/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2059 - accuracy: 0.9113 - val_loss: 0.2432 - val_accuracy: 0.9080
# Epoch 19/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.2009 - accuracy: 0.9130 - val_loss: 0.2372 - val_accuracy: 0.9129
# Epoch 20/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1861 - accuracy: 0.9159 - val_loss: 0.2355 - val_accuracy: 0.9148
# Epoch 21/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1891 - accuracy: 0.9224 - val_loss: 0.2362 - val_accuracy: 0.9123
# Epoch 22/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1820 - accuracy: 0.9257 - val_loss: 0.2359 - val_accuracy: 0.9179
# Epoch 23/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1727 - accuracy: 0.9312 - val_loss: 0.2238 - val_accuracy: 0.9216
# Epoch 24/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1569 - accuracy: 0.9348 - val_loss: 0.2381 - val_accuracy: 0.9228
# Epoch 25/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1503 - accuracy: 0.9371 - val_loss: 0.2923 - val_accuracy: 0.9240
# Epoch 26/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1490 - accuracy: 0.9379 - val_loss: 0.2494 - val_accuracy: 0.9203
# Epoch 27/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1382 - accuracy: 0.9456 - val_loss: 0.2977 - val_accuracy: 0.9277
# Epoch 28/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1476 - accuracy: 0.9461 - val_loss: 0.2556 - val_accuracy: 0.9284
# Epoch 29/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1210 - accuracy: 0.9506 - val_loss: 0.2549 - val_accuracy: 0.9290
# Epoch 30/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1191 - accuracy: 0.9510 - val_loss: 0.3036 - val_accuracy: 0.9253
# Epoch 31/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1186 - accuracy: 0.9560 - val_loss: 0.2479 - val_accuracy: 0.9246
# Epoch 32/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1162 - accuracy: 0.9555 - val_loss: 0.2878 - val_accuracy: 0.9253
# Epoch 33/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1026 - accuracy: 0.9589 - val_loss: 0.2624 - val_accuracy: 0.9296
# Epoch 34/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1000 - accuracy: 0.9615 - val_loss: 0.3052 - val_accuracy: 0.9259
# Epoch 35/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1048 - accuracy: 0.9597 - val_loss: 0.3005 - val_accuracy: 0.9308
# Epoch 36/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0969 - accuracy: 0.9632 - val_loss: 0.3173 - val_accuracy: 0.9284
# Epoch 37/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0862 - accuracy: 0.9682 - val_loss: 0.3442 - val_accuracy: 0.9314
# Epoch 38/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0822 - accuracy: 0.9702 - val_loss: 0.3675 - val_accuracy: 0.9302
# Epoch 39/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0864 - accuracy: 0.9711 - val_loss: 0.3154 - val_accuracy: 0.9321
# Epoch 40/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0855 - accuracy: 0.9700 - val_loss: 0.3379 - val_accuracy: 0.9179
# Epoch 41/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0821 - accuracy: 0.9719 - val_loss: 0.3064 - val_accuracy: 0.9302
# Epoch 42/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.1009 - accuracy: 0.9649 - val_loss: 0.2596 - val_accuracy: 0.9166
# Epoch 43/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0850 - accuracy: 0.9722 - val_loss: 0.3502 - val_accuracy: 0.9259
# Epoch 44/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0788 - accuracy: 0.9710 - val_loss: 0.3105 - val_accuracy: 0.9314
# Epoch 45/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0730 - accuracy: 0.9744 - val_loss: 0.4146 - val_accuracy: 0.9296
# Epoch 46/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0815 - accuracy: 0.9699 - val_loss: 0.3103 - val_accuracy: 0.9308
# Epoch 47/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0747 - accuracy: 0.9750 - val_loss: 0.3355 - val_accuracy: 0.9333
# Epoch 48/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0705 - accuracy: 0.9771 - val_loss: 0.3176 - val_accuracy: 0.9321
# Epoch 49/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0655 - accuracy: 0.9781 - val_loss: 0.4091 - val_accuracy: 0.9290
# Epoch 50/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0702 - accuracy: 0.9785 - val_loss: 0.4336 - val_accuracy: 0.9308
# Epoch 51/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0809 - accuracy: 0.9736 - val_loss: 0.3353 - val_accuracy: 0.9333
# Epoch 52/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0551 - accuracy: 0.9813 - val_loss: 0.3608 - val_accuracy: 0.9314
# Epoch 53/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0558 - accuracy: 0.9798 - val_loss: 0.3638 - val_accuracy: 0.9271
# Epoch 54/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0627 - accuracy: 0.9754 - val_loss: 0.3092 - val_accuracy: 0.9302
# Epoch 55/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0612 - accuracy: 0.9781 - val_loss: 0.4290 - val_accuracy: 0.9271
# Epoch 56/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0661 - accuracy: 0.9764 - val_loss: 0.3660 - val_accuracy: 0.9271
# Epoch 57/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0536 - accuracy: 0.9811 - val_loss: 0.4420 - val_accuracy: 0.9271
# Epoch 58/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0617 - accuracy: 0.9768 - val_loss: 0.3676 - val_accuracy: 0.9345
# Epoch 59/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0515 - accuracy: 0.9811 - val_loss: 0.5315 - val_accuracy: 0.9308
# Epoch 60/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0564 - accuracy: 0.9793 - val_loss: 0.3796 - val_accuracy: 0.9308
# Epoch 61/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0608 - accuracy: 0.9774 - val_loss: 0.4597 - val_accuracy: 0.9284
# Epoch 62/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0513 - accuracy: 0.9815 - val_loss: 0.4305 - val_accuracy: 0.9345
# Epoch 63/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0622 - accuracy: 0.9771 - val_loss: 0.3945 - val_accuracy: 0.9321
# Epoch 64/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0485 - accuracy: 0.9827 - val_loss: 0.3830 - val_accuracy: 0.9277
# Epoch 65/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0473 - accuracy: 0.9847 - val_loss: 0.4436 - val_accuracy: 0.9327
# Epoch 66/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0514 - accuracy: 0.9819 - val_loss: 0.5111 - val_accuracy: 0.9345
# Epoch 67/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0440 - accuracy: 0.9849 - val_loss: 0.5251 - val_accuracy: 0.9339
# Epoch 68/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0532 - accuracy: 0.9798 - val_loss: 0.3926 - val_accuracy: 0.9290
# Epoch 69/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0435 - accuracy: 0.9853 - val_loss: 0.4210 - val_accuracy: 0.9308
# Epoch 70/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0537 - accuracy: 0.9827 - val_loss: 0.4445 - val_accuracy: 0.9333
# Epoch 71/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0411 - accuracy: 0.9869 - val_loss: 0.5580 - val_accuracy: 0.9345
# Epoch 72/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0474 - accuracy: 0.9832 - val_loss: 0.4890 - val_accuracy: 0.9364
# Epoch 73/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0462 - accuracy: 0.9839 - val_loss: 0.4164 - val_accuracy: 0.9333
# Epoch 74/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0470 - accuracy: 0.9844 - val_loss: 0.4332 - val_accuracy: 0.9333
# Epoch 75/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0433 - accuracy: 0.9838 - val_loss: 0.5366 - val_accuracy: 0.9364
# Epoch 76/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0381 - accuracy: 0.9878 - val_loss: 0.5199 - val_accuracy: 0.9327
# Epoch 77/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0466 - accuracy: 0.9830 - val_loss: 0.4228 - val_accuracy: 0.9358
# Epoch 78/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0511 - accuracy: 0.9808 - val_loss: 0.3922 - val_accuracy: 0.9339
# Epoch 79/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0472 - accuracy: 0.9836 - val_loss: 0.4783 - val_accuracy: 0.9345
# Epoch 80/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0442 - accuracy: 0.9841 - val_loss: 0.5395 - val_accuracy: 0.9327
# Epoch 81/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0377 - accuracy: 0.9879 - val_loss: 0.3576 - val_accuracy: 0.9296
# Epoch 82/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0531 - accuracy: 0.9822 - val_loss: 0.4328 - val_accuracy: 0.9321
# Epoch 83/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0418 - accuracy: 0.9881 - val_loss: 0.4762 - val_accuracy: 0.9345
# Epoch 84/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0363 - accuracy: 0.9890 - val_loss: 0.4859 - val_accuracy: 0.9327
# Epoch 85/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0382 - accuracy: 0.9847 - val_loss: 0.4347 - val_accuracy: 0.9364
# Epoch 86/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0389 - accuracy: 0.9861 - val_loss: 0.5295 - val_accuracy: 0.9358
# Epoch 87/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0356 - accuracy: 0.9870 - val_loss: 0.5094 - val_accuracy: 0.9333
# Epoch 88/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0485 - accuracy: 0.9819 - val_loss: 0.6168 - val_accuracy: 0.9358
# Epoch 89/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0405 - accuracy: 0.9869 - val_loss: 0.4337 - val_accuracy: 0.9302
# Epoch 90/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0515 - accuracy: 0.9842 - val_loss: 0.3932 - val_accuracy: 0.9314
# Epoch 91/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0342 - accuracy: 0.9887 - val_loss: 0.5901 - val_accuracy: 0.9339
# Epoch 92/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0435 - accuracy: 0.9867 - val_loss: 0.4285 - val_accuracy: 0.9345
# Epoch 93/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0422 - accuracy: 0.9855 - val_loss: 0.5232 - val_accuracy: 0.9302
# Epoch 94/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0435 - accuracy: 0.9856 - val_loss: 0.4241 - val_accuracy: 0.9302
# Epoch 95/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0361 - accuracy: 0.9873 - val_loss: 0.4289 - val_accuracy: 0.9327
# Epoch 96/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0356 - accuracy: 0.9883 - val_loss: 0.4398 - val_accuracy: 0.9314
# Epoch 97/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0430 - accuracy: 0.9859 - val_loss: 0.5233 - val_accuracy: 0.9339
# Epoch 98/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0348 - accuracy: 0.9879 - val_loss: 0.4434 - val_accuracy: 0.9327
# Epoch 99/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0377 - accuracy: 0.9866 - val_loss: 0.6429 - val_accuracy: 0.9351
# Epoch 100/100
# 203/203 [==============================] - 7s 33ms/step - loss: 0.0355 - accuracy: 0.9879 - val_loss: 0.5559 - val_accuracy: 0.9358

# %%
#Instead f checking for each image, we can evaluate the model on all test data
#for accuracy
################################################################

#We can load the trained model, so we don't have to train again for 300 epochs!
from keras.models import load_model

#model = load_model(modelpath+'/2DCNN_BASE_WITHOUT_AUG.h5')

#For 300 epochs, giving 82.5% accuracy

_, acc = model.evaluate(X_test, y_test)
print("Test accuracy = ", (acc * 100.0), "%")
# Out:
# 51/51 [==============================] - 1s 11ms/step - loss: 0.5559 - accuracy: 0.9358
# Test accuracy =  93.57628226280212 %

# %%
#How do we know how it is doing for parasitized vs uninfected? 
################################################################

#Confusion matrix
#We compare labels and plot them based on correct or wrong predictions.
#Since sigmoid outputs probabilities we need to apply threshold to convert to label.


#Check the confusion matrix for various thresholds. Which one is good?
#Need to balance positive, negative, false positive and false negative. 
#ROC can help identify the right threshold.
##################################################################
"""
Receiver Operating Characteristic (ROC) Curve is a plot that helps us 
visualize the performance of a binary classifier when the threshold is varied. 
"""
#ROC
from sklearn.metrics import roc_curve
y_preds = model.predict(X_test).ravel()

fpr, tpr, thresholds = roc_curve(y_test, y_preds)
plt.figure(1)
plt.plot([0, 1], [0, 1], 'y--')
plt.plot(fpr, tpr, marker='.')
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.savefig(figpath+'/VGG3_ROC_CURVE_WITH_AUG.png', bbox_inches='tight')
plt.show()
# Out:
# 51/51 [==============================] - 1s 10ms/step

# %%
"""
#One way to find the best threshold once we calculate the true positive 
and false positive rates is ...
The optimal cut off point would be where “true positive rate” is high 
and the “false positive rate” is low. 
Based on this logic let us find the threshold where tpr-(1-fpr) is zero (or close to 0)
"""
import pandas as pd
i = np.arange(len(tpr)) 
roc = pd.DataFrame({'tf' : pd.Series(tpr-(1-fpr), index=i), 'thresholds' : pd.Series(thresholds, index=i)})
ideal_roc_thresh = roc.iloc[(roc.tf-0).abs().argsort()[:1]]  #Locate the point where the value is close to 0
print("Ideal threshold is: ", ideal_roc_thresh['thresholds']) 

#Now use this threshold value in the confusion matrix to visualize the balance
#between tp, fp, fp, and fn
# Out:
# Ideal threshold is:  119    0.000059
# Name: thresholds, dtype: float32

# %%
#AUC
#Area under the curve (AUC) for ROC plot can be used to understand hpw well a classifier 
#is performing. 
#% chance that the model can distinguish between positive and negative classes.

from sklearn.metrics import auc
auc_value = auc(fpr, tpr)
print("Area under curve, AUC = ", auc_value)
# Out:
# Area under curve, AUC =  0.9871159862791663

# %%
#########################################
mythreshold = 0.0001

y_preds= (model.predict(X_test)>= mythreshold).astype(int)
from sklearn.metrics import confusion_matrix, f1_score, classification_report

cm = confusion_matrix(y_test, y_preds)
print('Confusion Matrix\n', cm)
import seaborn as sns
hmp = sns.heatmap(cm, annot=True)
hmp_fig = hmp.get_figure()
hmp_fig.savefig(figpath+'/VGG3_heatmap_WITHOUT_AUG.png', dpi = 400)


f1scores_per_class = (f1_score(y_test, y_preds, average=None))
average_fscore_macro = (f1_score(y_test, y_preds, average="macro"))
average_fscore_weighted = (f1_score(y_test, y_preds, average="weighted"))
print('Average F1 Score per class:', f1scores_per_class)
print('Average_Macro F1 Score of the Model:', average_fscore_macro)
print('Average_Weighted F1 score of the Model:', average_fscore_weighted)
print(f'Test Accuracy of the Model: {acc * 100}%')
# Out:
# 51/51 [==============================] - 1s 10ms/step
# Confusion Matrix
#  [[1194  240]
#  [  32  153]]
# Average F1 Score per class: [0.89774436 0.52941176]
# Average_Macro F1 Score of the Model: 0.713578062804069
# Average_Weighted F1 score of the Model: 0.855655707229415
# Test Accuracy of the Model: 93.57628226280212%

# %%
n=12  #Select the index of image to be loaded for testing
img = X_test[n]
plt.imshow(img)
input_img = np.expand_dims(img, axis=0) #Expand dims so the input is (num images, x, y, c)
print("The prediction for this image is: ", (model.predict(input_img)>=mythreshold).astype(int))
print("The actual label for this image is: ", y_test[n] ," [1 = EFFECTED & 0= NOT EFFECTED]")
# Out:
# 1/1 [==============================] - 0s 8ms/step
# The prediction for this image is:  [[1]]
# The actual label for this image is:  1  [1 = EFFECTED & 0= NOT EFFECTED]

# %%
import gc
del X_test, X_train, y_test, y_train
gc.collect()
# Out:
# 13870
