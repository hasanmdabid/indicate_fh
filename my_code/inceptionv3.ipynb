# %%
import os
import numpy as np
import logging
np.random.seed(50)
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
logging.getLogger('tensorflow').disabled = True
# machine learning
from keras.preprocessing import image
from keras.models import load_model
from keras.applications.imagenet_utils import preprocess_input, decode_predictions
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.metrics import roc_curve, auc, confusion_matrix, ConfusionMatrixDisplay
from numpy import loadtxt
from keras import Model, layers
from keras.applications.mobilenet_v2 import MobileNetV2

import tensorflow as tf
from keras.utils import Sequence
from random import shuffle
from clear_folder import clear_folder
import logging
from split_data import *
# for opening and loading image
import matplotlib.pyplot as plt
# Doing One hot encoding as classifier has multiple classes
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
datapath = '/home/abidhasan/Documents/Indicate_FH/data'
train_dir = '/home/abidhasan/Documents/Indicate_FH/train_val_test/train'
test_dir = '/home/abidhasan/Documents/Indicate_FH/train_val_test/test'
model_dir = '/home/abidhasan/Documents/Indicate_FH/saved_model/'
figpath = '/home/abidhasan/Documents/Indicate_FH/performance_figures'
checkpointpath = '/home/abidhasan/Documents/Indicate_FH/checkpoints/'
batch_size = 16
size = 299
dropout_rt = 0.5
image_size = (size, size)
n_channels = 3
epochs = 100
model_name = 'inceptionv3'
train_data_ratio = 0.8
val_data_ratio = 0.0
test_data_ratio = 0.2

# ModelCheckpoint callback saves a model at some interval.
# File name includes epoch and validation accuracy.


class DataGenerator(Sequence):
    def __init__(self, image_dir, batch_size, image_size, n_channels=3, shuffle=True):
        self.image_dir = image_dir
        self.batch_size = batch_size
        self.image_size = image_size
        self.n_channels = n_channels
        self.shuffle = shuffle
        self.supported_formats = ['.jpg', '.jpeg', '.png', '.gif', '.bmp']
        self.image_files, self.labels = self._load_image_files()
        self.indexes = np.arange(len(self.image_files))
        self.on_epoch_end()

    def __len__(self):
        return int(np.floor(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        indexes = self.indexes[index*self.batch_size:(index+1)*self.batch_size]
        batch_files = [self.image_files[k] for k in indexes]
        batch_labels = [self.labels[k] for k in indexes]

        X = np.empty((self.batch_size, *self.image_size,
                     self.n_channels), dtype=np.float32)
        y = np.empty((self.batch_size), dtype=np.float32)

        for i, file in enumerate(batch_files):
            image = self.load_image(file)
            if image is not None:
                X[i,] = image
                y[i] = batch_labels[i]

        return X, y

    def _load_image_files(self):
        image_files = []
        labels = []
        for label, category in enumerate(['not_effected', 'effected']):
            category_dir = os.path.join(self.image_dir, category)
            for file_name in os.listdir(category_dir):
                if any(file_name.lower().endswith(ext) for ext in self.supported_formats):
                    image_files.append(os.path.join(category_dir, file_name))
                    labels.append(label)
        return image_files, labels

    def load_image(self, image_path):
        try:
            image = tf.io.read_file(image_path)
            image = tf.image.decode_image(image, channels=self.n_channels)
            image = tf.image.resize(image, self.image_size)
            image = image / 255.0
            return image.numpy()
        except:
            # If the image cannot be decoded, return None
            return None

    def on_epoch_end(self):
        if self.shuffle:
            combined = list(zip(self.image_files, self.labels))
            np.random.shuffle(combined)
            self.image_files, self.labels = zip(*combined)

# %%
clear_folder('/home/abidhasan/Documents/Indicate_FH/train_val_test')
split_data(datapath, train_data_ratio, val_data_ratio, test_data_ratio)
# Out:
# Contents of '/home/abidhasan/Documents/Indicate_FH/train_val_test' have been cleared.
# Copying files: 8915 files [00:00, 9416.51 files/s]

# %%
# Function to count images in each class
import os


def count_images(directory):
    affected_count = len(os.listdir(os.path.join(directory, 'effected')))
    not_affected_count = len(os.listdir(
        os.path.join(directory, 'not_effected')))
    return affected_count, not_affected_count


# Count images in train set
train_affected_count, train_not_affected_count = count_images(train_dir)

# Count images in test set
test_affected_count, test_not_affected_count = count_images(test_dir)

# Print the counts
print(
    f'Train set: Affected - {train_affected_count}, Not Affected - {train_not_affected_count}')
print(
    f'Test set: Affected - {test_affected_count}, Not Affected - {test_not_affected_count}')
# Out:
# Train set: Affected - 712, Not Affected - 6420
# Test set: Affected - 178, Not Affected - 1605

# %%
# Import the inception model
from keras.applications.inception_v3 import InceptionV3

# %%
pre_trained_model = InceptionV3(input_shape=(size, size, n_channels),  # Shape of our images
                                include_top=False,  # Leave out the last fully connected layer
                                weights='imagenet')

# %%
for layer in pre_trained_model.layers:
  layer.trainable = True
  
x = layers.Flatten()(pre_trained_model.output)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.2)(x)
x = layers.Dense(64, activation='relu')(x)
x = layers.Dropout(0.1)(x)
predictions = layers.Dense(1,  activation='sigmoid')(x)
model = Model(pre_trained_model.input, predictions)


model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(
    learning_rate=0.0001), metrics=['accuracy'])

# %%
callbacks = [ModelCheckpoint(checkpointpath+model_name+'mdl_wts.hdf5', monitor='val_loss', mode='min', verbose=1, save_best_only=True),
             ReduceLROnPlateau(monitor='val_loss', factor=0.3, patience=2, verbose=1, mode='min', min_lr=0.00000001)]

# %%
train_gen = DataGenerator(image_dir=train_dir, batch_size=batch_size,
                          image_size=image_size, n_channels=n_channels)
test_gen = DataGenerator(image_dir=test_dir, batch_size=batch_size,
                         image_size=image_size, n_channels=n_channels, shuffle=False)

# Train the model in batches
steps_per_epoch = len(train_gen)
validation_steps = len(test_gen)

print("[INFO] training head...")
history = model.fit(train_gen, epochs=epochs, steps_per_epoch=steps_per_epoch,
                    validation_data=test_gen, validation_steps=validation_steps, callbacks=callbacks)
# Out:
# [INFO] training head...
# Epoch 1/100
# 445/445 [==============================] - ETA: 0s - loss: 0.2334 - accuracy: 0.9272
# Epoch 1: val_loss improved from inf to 0.12853, saving model to /home/abidhasan/Documents/Indicate_FH/checkpoints/inceptionv3mdl_wts.hdf5
# 445/445 [==============================] - 58s 97ms/step - loss: 0.2334 - accuracy: 0.9272 - val_loss: 0.1285 - val_accuracy: 0.9606 - lr: 1.0000e-04
# Epoch 2/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0885 - accuracy: 0.9701
# Epoch 2: val_loss improved from 0.12853 to 0.12842, saving model to /home/abidhasan/Documents/Indicate_FH/checkpoints/inceptionv3mdl_wts.hdf5
# 445/445 [==============================] - 43s 96ms/step - loss: 0.0885 - accuracy: 0.9701 - val_loss: 0.1284 - val_accuracy: 0.9673 - lr: 1.0000e-04
# Epoch 3/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0707 - accuracy: 0.9760
# Epoch 3: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0707 - accuracy: 0.9760 - val_loss: 0.1383 - val_accuracy: 0.9471 - lr: 1.0000e-04
# Epoch 4/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9829
# Epoch 4: val_loss did not improve from 0.12842
#
# Epoch 4: ReduceLROnPlateau reducing learning rate to 2.9999999242136255e-05.
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0503 - accuracy: 0.9829 - val_loss: 0.1618 - val_accuracy: 0.9589 - lr: 1.0000e-04
# Epoch 5/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0204 - accuracy: 0.9938
# Epoch 5: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0204 - accuracy: 0.9938 - val_loss: 0.1303 - val_accuracy: 0.9797 - lr: 3.0000e-05
# Epoch 6/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0102 - accuracy: 0.9965
# Epoch 6: val_loss did not improve from 0.12842
#
# Epoch 6: ReduceLROnPlateau reducing learning rate to 8.999999772640877e-06.
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0102 - accuracy: 0.9965 - val_loss: 0.1429 - val_accuracy: 0.9752 - lr: 3.0000e-05
# Epoch 7/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0040 - accuracy: 0.9993
# Epoch 7: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0040 - accuracy: 0.9993 - val_loss: 0.1655 - val_accuracy: 0.9764 - lr: 9.0000e-06
# Epoch 8/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0031 - accuracy: 0.9989
# Epoch 8: val_loss did not improve from 0.12842
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.6999998226528985e-06.
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0031 - accuracy: 0.9989 - val_loss: 0.1619 - val_accuracy: 0.9764 - lr: 9.0000e-06
# Epoch 9/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 0.9997
# Epoch 9: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0016 - accuracy: 0.9997 - val_loss: 0.1656 - val_accuracy: 0.9780 - lr: 2.7000e-06
# Epoch 10/100
# 445/445 [==============================] - ETA: 0s - loss: 8.1395e-04 - accuracy: 0.9999
# Epoch 10: val_loss did not improve from 0.12842
#
# Epoch 10: ReduceLROnPlateau reducing learning rate to 8.099999604382901e-07.
# 445/445 [==============================] - 42s 95ms/step - loss: 8.1395e-04 - accuracy: 0.9999 - val_loss: 0.1709 - val_accuracy: 0.9775 - lr: 2.7000e-06
# Epoch 11/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 11: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1730 - val_accuracy: 0.9769 - lr: 8.1000e-07
# Epoch 12/100
# 445/445 [==============================] - ETA: 0s - loss: 9.8007e-04 - accuracy: 0.9997
# Epoch 12: val_loss did not improve from 0.12842
#
# Epoch 12: ReduceLROnPlateau reducing learning rate to 2.4299998813148704e-07.
# 445/445 [==============================] - 42s 95ms/step - loss: 9.8007e-04 - accuracy: 0.9997 - val_loss: 0.1776 - val_accuracy: 0.9775 - lr: 8.1000e-07
# Epoch 13/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9999
# Epoch 13: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0011 - accuracy: 0.9999 - val_loss: 0.1769 - val_accuracy: 0.9764 - lr: 2.4300e-07
# Epoch 14/100
# 445/445 [==============================] - ETA: 0s - loss: 9.5303e-04 - accuracy: 0.9996
# Epoch 14: val_loss did not improve from 0.12842
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 7.289999643944612e-08.
# 445/445 [==============================] - 42s 94ms/step - loss: 9.5303e-04 - accuracy: 0.9996 - val_loss: 0.1764 - val_accuracy: 0.9764 - lr: 2.4300e-07
# Epoch 15/100
# 445/445 [==============================] - ETA: 0s - loss: 8.0265e-04 - accuracy: 0.9999
# Epoch 15: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 8.0265e-04 - accuracy: 0.9999 - val_loss: 0.1749 - val_accuracy: 0.9769 - lr: 7.2900e-08
# Epoch 16/100
# 445/445 [==============================] - ETA: 0s - loss: 6.6329e-04 - accuracy: 0.9999
# Epoch 16: val_loss did not improve from 0.12842
#
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.1869998079182552e-08.
# 445/445 [==============================] - 42s 94ms/step - loss: 6.6329e-04 - accuracy: 0.9999 - val_loss: 0.1767 - val_accuracy: 0.9769 - lr: 7.2900e-08
# Epoch 17/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9994
# Epoch 17: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0012 - accuracy: 0.9994 - val_loss: 0.1754 - val_accuracy: 0.9764 - lr: 2.1870e-08
# Epoch 18/100
# 445/445 [==============================] - ETA: 0s - loss: 8.1568e-04 - accuracy: 0.9997
# Epoch 18: val_loss did not improve from 0.12842
#
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1e-08.
# 445/445 [==============================] - 42s 95ms/step - loss: 8.1568e-04 - accuracy: 0.9997 - val_loss: 0.1767 - val_accuracy: 0.9769 - lr: 2.1870e-08
# Epoch 19/100
# 445/445 [==============================] - ETA: 0s - loss: 7.1300e-04 - accuracy: 0.9999
# Epoch 19: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.1300e-04 - accuracy: 0.9999 - val_loss: 0.1763 - val_accuracy: 0.9758 - lr: 1.0000e-08
# Epoch 20/100
# 445/445 [==============================] - ETA: 0s - loss: 9.0331e-04 - accuracy: 0.9997
# Epoch 20: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.0331e-04 - accuracy: 0.9997 - val_loss: 0.1764 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 21/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 21: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1772 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 22/100
# 445/445 [==============================] - ETA: 0s - loss: 8.5150e-04 - accuracy: 0.9996
# Epoch 22: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 8.5150e-04 - accuracy: 0.9996 - val_loss: 0.1750 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 23/100
# 445/445 [==============================] - ETA: 0s - loss: 9.5546e-04 - accuracy: 0.9996
# Epoch 23: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.5546e-04 - accuracy: 0.9996 - val_loss: 0.1763 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 24/100
# 445/445 [==============================] - ETA: 0s - loss: 5.4524e-04 - accuracy: 0.9999
# Epoch 24: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.4524e-04 - accuracy: 0.9999 - val_loss: 0.1751 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 25/100
# 445/445 [==============================] - ETA: 0s - loss: 7.6757e-04 - accuracy: 0.9997
# Epoch 25: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.6757e-04 - accuracy: 0.9997 - val_loss: 0.1757 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 26/100
# 445/445 [==============================] - ETA: 0s - loss: 9.2313e-04 - accuracy: 0.9996
# Epoch 26: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.2313e-04 - accuracy: 0.9996 - val_loss: 0.1764 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 27/100
# 445/445 [==============================] - ETA: 0s - loss: 7.3755e-04 - accuracy: 0.9999
# Epoch 27: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.3755e-04 - accuracy: 0.9999 - val_loss: 0.1766 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 28/100
# 445/445 [==============================] - ETA: 0s - loss: 6.6797e-04 - accuracy: 0.9999
# Epoch 28: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 6.6797e-04 - accuracy: 0.9999 - val_loss: 0.1767 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 29/100
# 445/445 [==============================] - ETA: 0s - loss: 8.1341e-04 - accuracy: 0.9999
# Epoch 29: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.1341e-04 - accuracy: 0.9999 - val_loss: 0.1767 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 30/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.9996
# Epoch 30: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0019 - accuracy: 0.9996 - val_loss: 0.1770 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 31/100
# 445/445 [==============================] - ETA: 0s - loss: 7.1440e-04 - accuracy: 0.9999
# Epoch 31: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.1440e-04 - accuracy: 0.9999 - val_loss: 0.1756 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 32/100
# 445/445 [==============================] - ETA: 0s - loss: 7.0166e-04 - accuracy: 0.9999
# Epoch 32: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.0166e-04 - accuracy: 0.9999 - val_loss: 0.1766 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 33/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 33: val_loss did not improve from 0.12842
# 445/445 [==============================] - 43s 96ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1776 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 34/100
# 445/445 [==============================] - ETA: 0s - loss: 6.1481e-04 - accuracy: 0.9999
# Epoch 34: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 6.1481e-04 - accuracy: 0.9999 - val_loss: 0.1758 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 35/100
# 445/445 [==============================] - ETA: 0s - loss: 8.2950e-04 - accuracy: 0.9996
# Epoch 35: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.2950e-04 - accuracy: 0.9996 - val_loss: 0.1777 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 36/100
# 445/445 [==============================] - ETA: 0s - loss: 6.8284e-04 - accuracy: 0.9999
# Epoch 36: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 6.8284e-04 - accuracy: 0.9999 - val_loss: 0.1774 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 37/100
# 445/445 [==============================] - ETA: 0s - loss: 8.5333e-04 - accuracy: 0.9999
# Epoch 37: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.5333e-04 - accuracy: 0.9999 - val_loss: 0.1764 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 38/100
# 445/445 [==============================] - ETA: 0s - loss: 5.9737e-04 - accuracy: 0.9999
# Epoch 38: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.9737e-04 - accuracy: 0.9999 - val_loss: 0.1766 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 39/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0020 - accuracy: 0.9997
# Epoch 39: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0020 - accuracy: 0.9997 - val_loss: 0.1766 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 40/100
# 445/445 [==============================] - ETA: 0s - loss: 6.1043e-04 - accuracy: 1.0000
# Epoch 40: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.1043e-04 - accuracy: 1.0000 - val_loss: 0.1768 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 41/100
# 445/445 [==============================] - ETA: 0s - loss: 6.4582e-04 - accuracy: 0.9997
# Epoch 41: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.4582e-04 - accuracy: 0.9997 - val_loss: 0.1776 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 42/100
# 445/445 [==============================] - ETA: 0s - loss: 8.8121e-04 - accuracy: 0.9997
# Epoch 42: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.8121e-04 - accuracy: 0.9997 - val_loss: 0.1771 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 43/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.9997
# Epoch 43: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0013 - accuracy: 0.9997 - val_loss: 0.1782 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 44/100
# 445/445 [==============================] - ETA: 0s - loss: 8.5750e-04 - accuracy: 0.9999
# Epoch 44: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.5750e-04 - accuracy: 0.9999 - val_loss: 0.1786 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 45/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.9997
# Epoch 45: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0010 - accuracy: 0.9997 - val_loss: 0.1764 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 46/100
# 445/445 [==============================] - ETA: 0s - loss: 7.2938e-04 - accuracy: 0.9999
# Epoch 46: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.2938e-04 - accuracy: 0.9999 - val_loss: 0.1770 - val_accuracy: 0.9758 - lr: 1.0000e-08
# Epoch 47/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.9996
# Epoch 47: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 0.0011 - accuracy: 0.9996 - val_loss: 0.1763 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 48/100
# 445/445 [==============================] - ETA: 0s - loss: 6.7341e-04 - accuracy: 0.9999
# Epoch 48: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.7341e-04 - accuracy: 0.9999 - val_loss: 0.1784 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 49/100
# 445/445 [==============================] - ETA: 0s - loss: 9.3968e-04 - accuracy: 0.9999
# Epoch 49: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.3968e-04 - accuracy: 0.9999 - val_loss: 0.1767 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 50/100
# 445/445 [==============================] - ETA: 0s - loss: 7.7512e-04 - accuracy: 0.9999
# Epoch 50: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.7512e-04 - accuracy: 0.9999 - val_loss: 0.1772 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 51/100
# 445/445 [==============================] - ETA: 0s - loss: 7.7365e-04 - accuracy: 0.9999
# Epoch 51: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.7365e-04 - accuracy: 0.9999 - val_loss: 0.1779 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 52/100
# 445/445 [==============================] - ETA: 0s - loss: 6.5234e-04 - accuracy: 0.9999
# Epoch 52: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.5234e-04 - accuracy: 0.9999 - val_loss: 0.1781 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 53/100
# 445/445 [==============================] - ETA: 0s - loss: 6.9918e-04 - accuracy: 0.9999
# Epoch 53: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.9918e-04 - accuracy: 0.9999 - val_loss: 0.1783 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 54/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.9996
# Epoch 54: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.1780 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 55/100
# 445/445 [==============================] - ETA: 0s - loss: 9.6807e-04 - accuracy: 0.9996
# Epoch 55: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.6807e-04 - accuracy: 0.9996 - val_loss: 0.1777 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 56/100
# 445/445 [==============================] - ETA: 0s - loss: 9.1852e-04 - accuracy: 0.9997
# Epoch 56: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.1852e-04 - accuracy: 0.9997 - val_loss: 0.1779 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 57/100
# 445/445 [==============================] - ETA: 0s - loss: 7.9153e-04 - accuracy: 0.9997
# Epoch 57: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 7.9153e-04 - accuracy: 0.9997 - val_loss: 0.1795 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 58/100
# 445/445 [==============================] - ETA: 0s - loss: 5.4794e-04 - accuracy: 0.9997
# Epoch 58: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.4794e-04 - accuracy: 0.9997 - val_loss: 0.1777 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 59/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9997
# Epoch 59: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0012 - accuracy: 0.9997 - val_loss: 0.1788 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 60/100
# 445/445 [==============================] - ETA: 0s - loss: 5.7535e-04 - accuracy: 0.9999
# Epoch 60: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.7535e-04 - accuracy: 0.9999 - val_loss: 0.1777 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 61/100
# 445/445 [==============================] - ETA: 0s - loss: 6.8539e-04 - accuracy: 0.9997
# Epoch 61: val_loss did not improve from 0.12842
# 445/445 [==============================] - 43s 96ms/step - loss: 6.8539e-04 - accuracy: 0.9997 - val_loss: 0.1772 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 62/100
# 445/445 [==============================] - ETA: 0s - loss: 5.6484e-04 - accuracy: 1.0000
# Epoch 62: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.6484e-04 - accuracy: 1.0000 - val_loss: 0.1781 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 63/100
# 445/445 [==============================] - ETA: 0s - loss: 7.5645e-04 - accuracy: 0.9999
# Epoch 63: val_loss did not improve from 0.12842
# 445/445 [==============================] - 43s 96ms/step - loss: 7.5645e-04 - accuracy: 0.9999 - val_loss: 0.1781 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 64/100
# 445/445 [==============================] - ETA: 0s - loss: 8.3400e-04 - accuracy: 1.0000
# Epoch 64: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.3400e-04 - accuracy: 1.0000 - val_loss: 0.1792 - val_accuracy: 0.9758 - lr: 1.0000e-08
# Epoch 65/100
# 445/445 [==============================] - ETA: 0s - loss: 7.4645e-04 - accuracy: 0.9999
# Epoch 65: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.4645e-04 - accuracy: 0.9999 - val_loss: 0.1787 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 66/100
# 445/445 [==============================] - ETA: 0s - loss: 7.2472e-04 - accuracy: 0.9997
# Epoch 66: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.2472e-04 - accuracy: 0.9997 - val_loss: 0.1784 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 67/100
# 445/445 [==============================] - ETA: 0s - loss: 8.0707e-04 - accuracy: 0.9996
# Epoch 67: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.0707e-04 - accuracy: 0.9996 - val_loss: 0.1777 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 68/100
# 445/445 [==============================] - ETA: 0s - loss: 6.7051e-04 - accuracy: 0.9997
# Epoch 68: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.7051e-04 - accuracy: 0.9997 - val_loss: 0.1784 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 69/100
# 445/445 [==============================] - ETA: 0s - loss: 7.2835e-04 - accuracy: 0.9997
# Epoch 69: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.2835e-04 - accuracy: 0.9997 - val_loss: 0.1805 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 70/100
# 445/445 [==============================] - ETA: 0s - loss: 8.4991e-04 - accuracy: 0.9997
# Epoch 70: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.4991e-04 - accuracy: 0.9997 - val_loss: 0.1794 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 71/100
# 445/445 [==============================] - ETA: 0s - loss: 5.9697e-04 - accuracy: 1.0000
# Epoch 71: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.9697e-04 - accuracy: 1.0000 - val_loss: 0.1782 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 72/100
# 445/445 [==============================] - ETA: 0s - loss: 7.3577e-04 - accuracy: 0.9999
# Epoch 72: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.3577e-04 - accuracy: 0.9999 - val_loss: 0.1803 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 73/100
# 445/445 [==============================] - ETA: 0s - loss: 6.8550e-04 - accuracy: 1.0000
# Epoch 73: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.8550e-04 - accuracy: 1.0000 - val_loss: 0.1802 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 74/100
# 445/445 [==============================] - ETA: 0s - loss: 7.3182e-04 - accuracy: 0.9999
# Epoch 74: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.3182e-04 - accuracy: 0.9999 - val_loss: 0.1780 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 75/100
# 445/445 [==============================] - ETA: 0s - loss: 5.8592e-04 - accuracy: 1.0000
# Epoch 75: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.8592e-04 - accuracy: 1.0000 - val_loss: 0.1786 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 76/100
# 445/445 [==============================] - ETA: 0s - loss: 8.4776e-04 - accuracy: 0.9999
# Epoch 76: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.4776e-04 - accuracy: 0.9999 - val_loss: 0.1793 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 77/100
# 445/445 [==============================] - ETA: 0s - loss: 8.1423e-04 - accuracy: 0.9997
# Epoch 77: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.1423e-04 - accuracy: 0.9997 - val_loss: 0.1810 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 78/100
# 445/445 [==============================] - ETA: 0s - loss: 8.9484e-04 - accuracy: 0.9997
# Epoch 78: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.9484e-04 - accuracy: 0.9997 - val_loss: 0.1786 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 79/100
# 445/445 [==============================] - ETA: 0s - loss: 5.7090e-04 - accuracy: 0.9999
# Epoch 79: val_loss did not improve from 0.12842
# 445/445 [==============================] - 43s 96ms/step - loss: 5.7090e-04 - accuracy: 0.9999 - val_loss: 0.1797 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 80/100
# 445/445 [==============================] - ETA: 0s - loss: 8.8592e-04 - accuracy: 0.9997
# Epoch 80: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.8592e-04 - accuracy: 0.9997 - val_loss: 0.1798 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 81/100
# 445/445 [==============================] - ETA: 0s - loss: 7.0784e-04 - accuracy: 0.9997
# Epoch 81: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.0784e-04 - accuracy: 0.9997 - val_loss: 0.1794 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 82/100
# 445/445 [==============================] - ETA: 0s - loss: 5.8495e-04 - accuracy: 0.9999
# Epoch 82: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.8495e-04 - accuracy: 0.9999 - val_loss: 0.1800 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 83/100
# 445/445 [==============================] - ETA: 0s - loss: 6.2262e-04 - accuracy: 0.9997
# Epoch 83: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.2262e-04 - accuracy: 0.9997 - val_loss: 0.1802 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 84/100
# 445/445 [==============================] - ETA: 0s - loss: 7.2720e-04 - accuracy: 0.9997
# Epoch 84: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.2720e-04 - accuracy: 0.9997 - val_loss: 0.1802 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 85/100
# 445/445 [==============================] - ETA: 0s - loss: 9.7440e-04 - accuracy: 0.9996
# Epoch 85: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 9.7440e-04 - accuracy: 0.9996 - val_loss: 0.1812 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 86/100
# 445/445 [==============================] - ETA: 0s - loss: 6.5952e-04 - accuracy: 1.0000
# Epoch 86: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.5952e-04 - accuracy: 1.0000 - val_loss: 0.1807 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 87/100
# 445/445 [==============================] - ETA: 0s - loss: 6.5226e-04 - accuracy: 0.9999
# Epoch 87: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 6.5226e-04 - accuracy: 0.9999 - val_loss: 0.1797 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 88/100
# 445/445 [==============================] - ETA: 0s - loss: 8.8088e-04 - accuracy: 0.9999
# Epoch 88: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 8.8088e-04 - accuracy: 0.9999 - val_loss: 0.1787 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 89/100
# 445/445 [==============================] - ETA: 0s - loss: 4.6193e-04 - accuracy: 0.9999
# Epoch 89: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 94ms/step - loss: 4.6193e-04 - accuracy: 0.9999 - val_loss: 0.1805 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 90/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.9993
# Epoch 90: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0012 - accuracy: 0.9993 - val_loss: 0.1789 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 91/100
# 445/445 [==============================] - ETA: 0s - loss: 7.6899e-04 - accuracy: 0.9997
# Epoch 91: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.6899e-04 - accuracy: 0.9997 - val_loss: 0.1796 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 92/100
# 445/445 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.9994
# Epoch 92: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 0.0014 - accuracy: 0.9994 - val_loss: 0.1794 - val_accuracy: 0.9764 - lr: 1.0000e-08
# Epoch 93/100
# 445/445 [==============================] - ETA: 0s - loss: 6.9781e-04 - accuracy: 0.9999
# Epoch 93: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.9781e-04 - accuracy: 0.9999 - val_loss: 0.1795 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 94/100
# 445/445 [==============================] - ETA: 0s - loss: 7.2116e-04 - accuracy: 0.9999
# Epoch 94: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.2116e-04 - accuracy: 0.9999 - val_loss: 0.1810 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 95/100
# 445/445 [==============================] - ETA: 0s - loss: 6.8290e-04 - accuracy: 0.9997
# Epoch 95: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.8290e-04 - accuracy: 0.9997 - val_loss: 0.1812 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 96/100
# 445/445 [==============================] - ETA: 0s - loss: 7.1062e-04 - accuracy: 0.9999
# Epoch 96: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 7.1062e-04 - accuracy: 0.9999 - val_loss: 0.1794 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 97/100
# 445/445 [==============================] - ETA: 0s - loss: 6.3569e-04 - accuracy: 0.9999
# Epoch 97: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.3569e-04 - accuracy: 0.9999 - val_loss: 0.1803 - val_accuracy: 0.9769 - lr: 1.0000e-08
# Epoch 98/100
# 445/445 [==============================] - ETA: 0s - loss: 5.4700e-04 - accuracy: 0.9999
# Epoch 98: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 5.4700e-04 - accuracy: 0.9999 - val_loss: 0.1814 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 99/100
# 445/445 [==============================] - ETA: 0s - loss: 6.6739e-04 - accuracy: 0.9997
# Epoch 99: val_loss did not improve from 0.12842
# 445/445 [==============================] - 43s 96ms/step - loss: 6.6739e-04 - accuracy: 0.9997 - val_loss: 0.1819 - val_accuracy: 0.9775 - lr: 1.0000e-08
# Epoch 100/100
# 445/445 [==============================] - ETA: 0s - loss: 6.3288e-04 - accuracy: 0.9999
# Epoch 100: val_loss did not improve from 0.12842
# 445/445 [==============================] - 42s 95ms/step - loss: 6.3288e-04 - accuracy: 0.9999 - val_loss: 0.1820 - val_accuracy: 0.9775 - lr: 1.0000e-08

# %%
model = load_model(checkpointpath+model_name+'mdl_wts.hdf5')
model.save(model_dir+model_name+'_'+f"{epochs}"+'.h5')

# %%
model = load_model(model_dir+model_name+'_'+f"{epochs}"+'.h5')

# %%
# Plotting the Model performcaes, train Vs Validation accuracy and train vs Validation Losses.
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('f"{model_name}" Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)
max_epoch = len(history.history['accuracy'])+1
epoch_list = list(range(1, max_epoch))
ax1.plot(epoch_list, history.history['accuracy'], label='Train Accuracy')
ax1.plot(
    epoch_list, history.history['val_accuracy'], label='Validation Accuracy')
ax1.set_xticks(np.arange(1, max_epoch, 5))
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")


ax2.plot(epoch_list, history.history['loss'], label='Train Loss')
ax2.plot(epoch_list, history.history['val_loss'], label='Validation Loss')
ax2.set_xticks(np.arange(1, max_epoch, 5))
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
plt.show()

plt.savefig(figpath+'/'+model_name+'_TRAIN_VS_VALIDATION_LOSS_with_weights.eps', format='eps', bbox_inches='tight')

# %%
# Evaluate the model on the test data
loss, accuracy = model.evaluate(test_gen, steps=len(test_gen))
print(f'Test accuracy: {accuracy * 100:.2f}%')

# Get predictions for the test dataset
predictions = model.predict(test_gen, steps=len(test_gen))
predicted_classes = (predictions > 0.5).astype("int32")

# Get true labels and predictions
true_labels = []
for i in range(len(test_gen)):
    _, labels = test_gen[i]
    true_labels.extend(labels)

true_labels = np.array(true_labels)

# Calculate ROC curve and AUC
fpr, tpr, thresholds = roc_curve(true_labels, predictions)
roc_auc = auc(fpr, tpr)

# Plot the ROC curve
plt.figure(figsize=(10, 5))
plt.plot(fpr, tpr, color='darkorange', lw=2,
         label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
plt.savefig(figpath+'/'+model_name+'_ROC.eps', format='eps', bbox_inches='tight')
# Out:
# 111/111 [==============================] - 7s 64ms/step - loss: 0.1284 - accuracy: 0.9673
# Test accuracy: 96.73%
# 111/111 [==============================] - 7s 64ms/step

# %%
# Compute the confusion matrix
cm = confusion_matrix(true_labels, predicted_classes)

# Display the confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[
                              'Not Affected', 'Affected'])
disp.plot(cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.show()

plt.savefig(figpath+'/'+model_name+'_CM.eps', format='eps', bbox_inches='tight')

# %%
from sklearn.metrics import f1_score

# Assuming true_labels and predicted_classes are your true labels and predicted labels respectively
f1_micro = f1_score(true_labels, predicted_classes, average='micro')
f1_macro = f1_score(true_labels, predicted_classes, average='macro')

print(f"F1 Score (Micro): {f1_micro}")
print(f"F1 Score (Macro): {f1_macro}")
# Out:
# F1 Score (Micro): 0.9673423423423423
# F1 Score (Macro): 0.9076154806491885

# %%
from sklearn.metrics import precision_recall_fscore_support, confusion_matrix

# Calculate the confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_classes)

# Calculate precision, recall, and F1 score for each class
precisions, recalls, f1s, _ = precision_recall_fscore_support(true_labels, predicted_classes)

# Calculate micro and macro averages
precision_micro = precision_recall_fscore_support(
    true_labels, predicted_classes, average='micro')[0]
recall_micro = precision_recall_fscore_support(
    true_labels, predicted_classes, average='micro')[1]
f1_micro = precision_recall_fscore_support(true_labels, predicted_classes, average='micro')[2]

precision_macro = precision_recall_fscore_support(
    true_labels, predicted_classes, average='macro')[0]
recall_macro = precision_recall_fscore_support(
    true_labels, predicted_classes, average='macro')[1]
f1_macro = precision_recall_fscore_support(true_labels, predicted_classes, average='macro')[2]

# Print the results
print("Per-class precision: ", precisions)
print("Per-class recall: ", recalls)
print("Per-class F1 scores: ", f1s)

print(f"Micro Precision: {precision_micro}")
print(f"Micro Recall: {recall_micro}")
print(f"Micro F1 Score: {f1_micro}")

print(f"Macro Precision: {precision_macro}")
print(f"Macro Recall: {recall_macro}")
print(f"Macro F1 Score: {f1_macro}")
# Out:
# Per-class precision:  [0.98373984 0.81920904]
# Per-class recall:  [0.98006231 0.84795322]
# Per-class F1 scores:  [0.98189763 0.83333333]
# Micro Precision: 0.9673423423423423
# Micro Recall: 0.9673423423423423
# Micro F1 Score: 0.9673423423423423
# Macro Precision: 0.9014744384731983
# Macro Recall: 0.9140077608351096
# Macro F1 Score: 0.9076154806491885

# %%
import matplotlib.pyplot as plt
import numpy as np

# Data for plotting
classes = np.unique(true_labels)
x = np.arange(len(classes))

# Plot precision, recall, and F1 scores
fig, ax = plt.subplots()
bar_width = 0.2

ax.bar(x - bar_width, precisions, bar_width, label='Precision')
ax.bar(x, recalls, bar_width, label='Recall')
ax.bar(x + bar_width, f1s, bar_width, label='F1 Score')

# Add some text for labels, title and axes ticks
ax.set_xlabel('Classes')
ax.set_ylabel('Scores')
ax.set_title('Precision, Recall, and F1 Scores by Class')
ax.set_xticks(x)
ax.set_xticklabels(classes)
ax.legend()

# Save plot as EPS file
plt.savefig(figpath+'/'+model_name+'_metrics_plot.eps', format='eps', bbox_inches='tight')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Get the actual number of affected and not affected images in the test set
actual_affected = sum(true_labels)
actual_not_affected = len(true_labels) - actual_affected

# Get the predicted number of affected and not affected images
predicted_affected = sum(predicted_classes)
predicted_not_affected = len(predicted_classes) - predicted_affected

# Print the counts
print("Actual:")
print(f"Affected: {actual_affected}, Not Affected: {actual_not_affected}")
print("\nPredicted:")
print(
    f"Affected: {predicted_affected}, Not Affected: {predicted_not_affected}")
# Out:
# Actual:
# Affected: 171.0, Not Affected: 1605.0
#
# Predicted:
# Affected: [177], Not Affected: [1599]
